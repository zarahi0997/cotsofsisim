# %%
zara077= tuple([1,2,3,4,5])
print(zara[2])
# Out:
#   Cell In[3], line 1
#     zara= tuple([1,2,3,4,5
#                           ^
# SyntaxError: incomplete input

# %%
cruz= tuple("vanessa,", "esta", "enamorada") 
zara= tuple(["Romina", "se", "va", "a", "casar"]
hdez = zara077+cruz
print(rolux)
# Out:
#   Cell In[5], line 2
#     zara= tuple(["Romina", "se", "va ¿", "a", "casar"]
#                ^
# SyntaxError: '(' was never closed

# %%
flop = tuple([1,2,3])
flop1 = flop[2] 
flop2 = flop[0] 
flop3 = flop[1] 
print(flop1,flop2,flop3)
# Out:
#   Cell In[7], line 4
#     flop3 = flop[1] print(flop1,flop2,flop3)
#                     ^
# SyntaxError: invalid syntax

# %%
enamorada = tuple([1,3,5,7,9])
feo= enamorada[3]
print(feo)
# Out:
# 7

# %%
eduardo=tuple([2,3,4,5,6]) 
print(eduardo[2:5])
# Out:
# (4, 5, 6)

# %%
pozole=tuple([10,20,30,40,50]) 
tacos= len (pozole
