# %%
#Texto llenado los espacios blanco 

#mi nombre es __ y tengo años de edad. 
#Tambien, siempre he querido ser __
#Gracias por leer me!

nombre= input("Cual es tu nombre") 
edad= input("Que edad tienes") 
profesion= input("Que deseas estudiar") 
print("Mi nombre es", nombre , "y tengo", edad , "años de edad. Tambien siempre he querido ser", profesion , "¡Gracias!"

Cual es tu nombre: Ana 
Que edad tienes: 35
Que deseas estudiar: Contabilidad 
Mi nombre es Ana y tengo 35 años de edad. Tambien siempre he querido ser contabilidad ¡Gracias por leerme!
# Out:
#   Cell In[1], line 15
#     Mi nombre es Ana y tengo 35 años de edad. Tambien siempre he querido ser contabilidad ¡Gracias por leerme!
#                                                                                           ^
# SyntaxError: invalid character '¡' (U+00A1)
